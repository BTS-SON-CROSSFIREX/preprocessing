# %%
import pandas as pd
import numpy as np
import string
import preprocessor as p
import re
from nltk.corpus import stopwords

# %%
df = pd.read_csv("overwatch_2022-01-01_2022-05-05tweetdata.csv", encoding='UTF-8')

# %%
df = df[['Text', 'Username', 'Like']]

# %%
df
# Out:
#                                                    Text         Username  Like
# 0     Heyooooo~ we doing a chill, comfy strem. Uhm.....       swagberryy     0
# 1     Time for @PlayOverwatch beta fun. Grogu and I ...  DrunkenMonk_C38     0
# 2     🌸¡Wiwitoos! Hoy estaremos jugando Overwatch 2 ...      ZabyMilbath    18
# 3     Overwatch: Origins Edition\nGiving You the Hoo...     Kingomiwater     0
# 4     @Todokonho @primegaming @PlayOverwatch https:/...         ogulagui     0
# ...                                                 ...              ...   ...
# 996   @RoofHanzo was long at night, almost closed po...        RainbIows     0
# 997   @DENDE_MUSCLE the difference is only noticeabl...        x1JayyJ1x     1
# 998   ╱╱     eyo  if  you  have  overwatch  and  eve...        siigiloso     5
# 999                Overwatch tem cada mulher LINDA, pqp  dEtzinho23mais1     1
# 1000  they wont give me beta for overwatch or dragon...     charmedVirus     0
#
# [1001 rows x 3 columns]

# %%
# 전처리 함수 내 사용
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is", "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are", "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have", "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have", "&gt;" : "is greater than", "&lt;" : "is less than", "&nbsp;": " ", "&amp;" : "and", "&quot;" : '"'}


def preprocessing(data) :
    data = re.sub('’|‘|´|`', '\'', data)
    data = re.sub('\\n', ' ', data)
    # lowering
    data = data.lower()
    #prevent removing "leage of legends" 
    data = re.sub('league of legends', 'leagueoflegends', data)
    # normalize abbreviation
    data = ' '.join([contractions[t] if t in contractions else t for t in data.split(" ")])
    # clean corpus to remove emoji and URL
    data = p.clean(data)
    # remove numbers and punctuations
    data = re.sub(r'[^A-Za-z ]', ' ', data)
    # remove duplicated alphabets
    data = re.sub(r'([A-Za-z])\1{2,}', r'\1', data)
    data = ' '.join(data.split())
    
    return data

# 전처리
df['Text'] = df['Text'].apply(lambda x : preprocessing(x))
df_temp = df[df['Text'] == ''].index
df = df.drop(df_temp)

# %%
df
# Out:
#                                                    Text         Username  Like
# 0     heyo we doing a chill comfy strem uhm playing ...       swagberryy     0
# 1     time for beta fun grogu and i are ready to cli...  DrunkenMonk_C38     0
# 2     wiwitoos hoy estaremos jugando overwatch beta ...      ZabyMilbath    18
# 3     overwatch origins edition giving you the hook ...     Kingomiwater     0
# 5     liked on youtube new overwatch nano boost voic...    Spyrokid77666     0
# ...                                                 ...              ...   ...
# 996   was long at night almost closed position for s...        RainbIows     0
# 997   the difference is only noticeable if you playe...        x1JayyJ1x     1
# 998   eyo if you have overwatch and ever wanna play ...        siigiloso     5
# 999                 overwatch tem cada mulher linda pqp  dEtzinho23mais1     1
# 1000  they wont give me beta for overwatch or dragon...     charmedVirus     0
#
# [908 rows x 3 columns]

# %%
# 불용어 사진
stop_words = set(stopwords.words('english')) 

def approx_english_detection(line) :
    total_words = line.split()
    stops_num = 0;
    for w in total_words: 
        if w in stop_words : stops_num += 1
    if(stops_num > 1) : return 'en'
    return 'other'

# %%
df['approx'] = df['Text'].apply(lambda x : approx_english_detection(x))

# %%
df
# Out:
#                                                    Text         Username  \
# 0     heyo we doing a chill comfy strem uhm playing ...       swagberryy
# 1     time for beta fun grogu and i are ready to cli...  DrunkenMonk_C38
# 2     wiwitoos hoy estaremos jugando overwatch beta ...      ZabyMilbath
# 3     overwatch origins edition giving you the hook ...     Kingomiwater
# 5     liked on youtube new overwatch nano boost voic...    Spyrokid77666
# ...                                                 ...              ...
# 996   was long at night almost closed position for s...        RainbIows
# 997   the difference is only noticeable if you playe...        x1JayyJ1x
# 998   eyo if you have overwatch and ever wanna play ...        siigiloso
# 999                 overwatch tem cada mulher linda pqp  dEtzinho23mais1
# 1000  they wont give me beta for overwatch or dragon...     charmedVirus
#
#       Like approx papago
# 0        0     en     en
# 1        0     en     en
# ...

# %%
df['approx'].value_counts('en')
# Out:
# en       0.615639
# other    0.384361
# Name: approx, dtype: float64

# %%
def papago_detection(line) :
    if len(line) < 3: return ''
    encQuery = urllib.parse.quote(line)
    data = "query=" + encQuery
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode == 200):
        return response.read().decode('utf-8')[13:15] 
    return 'error'

# %%
df['papago'] = df['Text'].apply(lambda x : papago_detection(x))

# %%
df
# Out:
#                                                    Text         Username  \
# 0     heyo we doing a chill comfy strem uhm playing ...       swagberryy
# 1     time for beta fun grogu and i are ready to cli...  DrunkenMonk_C38
# 2     wiwitoos hoy estaremos jugando overwatch beta ...      ZabyMilbath
# 3     overwatch origins edition giving you the hook ...     Kingomiwater
# 5     liked on youtube new overwatch nano boost voic...    Spyrokid77666
# ...                                                 ...              ...
# 996   was long at night almost closed position for s...        RainbIows
# 997   the difference is only noticeable if you playe...        x1JayyJ1x
# 998   eyo if you have overwatch and ever wanna play ...        siigiloso
# 999                 overwatch tem cada mulher linda pqp  dEtzinho23mais1
# 1000  they wont give me beta for overwatch or dragon...     charmedVirus
#
#       Like approx papago
# 0        0     en     en
# 1        0     en     en
# ...

# %%
# case 1 : 유사 알고리즘이 영어이면서 파파고가 영어가 아닌 경우
case1 = df[(df['approx'] == 'en') & (df['papago'] != 'en')]
print(case1.count())
# Out:
# Text        40
# Username    40
# Like        40
# approx      40
# papago      40
# dtype: int64

# %%
# case 2 : 유사 알고리즘이 영어이면서 파파고가 영어인 경우
case2 = df[(df['approx'] == 'en') & (df['papago'] == 'en')]
print(case2.count())
# Out:
# Text        612
# Username    612
# Like        612
# approx      612
# papago      612
# dtype: int64

# %%
# case 3 : 유사 알고리즘이 영어가 아니면서 파파고가 영어가 아닌 경우 
case3 = df[(df['approx'] != 'en') & (df['papago'] != 'en')]
print(case3.count())
# Out:
# Text        98
# Username    98
# Like        98
# approx      98
# papago      98
# dtype: int64

# %%
# case 3 : 유사 알고리즘이 영어가 아니면서 파파고가 영어인 경우 
case4 = df[(df['approx'] != 'en') & (df['papago'] == 'en')]
print(case4.count())
# Out:
# Text        158
# Username    158
# Like        158
# approx      158
# papago      158
# dtype: int64
